# %%
import numpy as np

from CML_tool.Utils import round_up_sig_figs

# %%
numbers = np.array([0.00010001, 0.99999, 0.132400001, 1.34567, -2.4565, -0.999991, 0.124000099])

# %%
[f'num is {str(round_up_sig_figs(num, 3))}' for num in numbers]
# Out:
# ['num is 0.000101',
#  'num is 1.0',
#  'num is 0.133',
#  'num is 1.35',
#  'num is -2.46',
#  'num is -1.0',
#  'num is 0.125']
