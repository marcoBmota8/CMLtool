# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import scienceplots
plt.style.use('science')

from CML_tool.ExplorativePlots import kde_rugplot_multivar

# %%
df = pd.DataFrame({
    'A': np.random.normal(0, 1, 200),
    'B': np.random.normal(2, 0.5, 200),
    'C': np.random.normal(-1, 1.5, 200)
})

# %%
fig = kde_rugplot_multivar(
    df,
    kernel='epanechnikov',
    kde_alpha=1,
    figsize=(7,5),
    bandwidth=0.5,
    ext_perc=5,
    show=True
    )
