# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import scienceplots
plt.style.use('science')

from CML_tool.ExplorativePlots import kde_rugplot_multivar

# %%
data_dict = {
    'A': np.random.normal(0, 1, 100),
    'B': np.random.normal(2, 0.5, 750),
    'C': np.random.normal(-1, 1.5, 200)
}

df =pd.DataFrame({
    'A': np.random.normal(0, 1, 100),
    'B': np.random.normal(2, 0.5, 100),
    'C': np.random.normal(-1, 1.5, 100)
})

# %%
fig = kde_rugplot_multivar(
    df,
    figsize=(7,5),
    show=True
    )

fig2 = kde_rugplot_multivar(
    data_dict,
    figsize=(7,5),
    show=True
    )
